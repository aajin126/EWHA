# %%
# stop_words 정의
stop_words = "\[ lt & ; ★ \n ! . \' , 아 휴 아이구 아이쿠 아이고 어 나 는 물론 역시 것이다 우리 저희 따라 의해 을 를 에 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼 어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다 하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 때문 그것 두 말하 알 그러나 받 못하 일 그런 또 문제 더 사회 많 그리고 좋 크 따르 중 나오 가지 씨 시키 만들 지금 생각하 그러 속 하나 집 살 모르 적 월 데 자신 안 어떤 내 내 경우 명 생각 시간 그녀 다시 이런 앞 보이 번 나 다른 어떻 여자 개 전 들 사실 이렇 점 싶 말 정도 좀 원 잘 통하 놓 줄거리".split(' ')

for element in stop_words:
    index = stop_words.index(element)
    stop_words[index] = element + ' '  # Add a space after the element

# stopwords_nospace = '\[ lt & ; ★ \n ! . \' ,'.split(' ')
# stop_words += stopwords_nospace
# stopwords_nospace = ['\[', 'lt', '&', ';', '★', '\n', '!', '.', '\'', ',']

#stop_words = "\[ lt & ; ★ \n ! . \' , 아 휴 아이구 아이쿠 아이고 어 나 물론 역시 것이다 우리 저희 따라 의해 을 를 에 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼 어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다 하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 때문 그것 두 말하 알 그러나 받 못하 일 그런 또 문제 더 사회 많 그리고 좋 크 따르 중 나오 가지 씨 시키 만들 지금 생각하 그러 속 하나 집 살 모르 적 월 데 자신 안 어떤 내 내 경우 명 생각 시간 그녀 다시 이런 앞 보이 번 나 다른 어떻 여자 개 전 들 사실 이렇 점 싶 말 정도 좀 원 잘 통하 놓 줄거리".split(' ')
stop_words
# Out:
# ['\\[ ',
#  'lt ',
#  '& ',
#  '; ',
#  '★ ',
#  '\n ',
#  '! ',
#  '. ',
#  "' ",
#  ', ',
#  '아 ',
#  '휴 ',
#  '아이구 ',
#  '아이쿠 ',
#  '아이고 ',
#  '어 ',
#  '나 ',
#  '는 ',
#  '물론 ',
#  '역시 ',
#  '것이다 ',
#  '우리 ',
#  '저희 ',
#  '따라 ',
#  '의해 ',
#  '을 ',
#  '를 ',
#  '에 ',
#  '가 ',
#  '으로 ',
#  '로 ',
#  '에게 ',
#  '뿐이다 ',
#  '의거하여 ',
#  '근거하여 ',
#  '입각하여 ',
#  '기준으로 ',
#  '예하면 ',
#  '예를 ',
#  '들면 ',
#  '들자면 ',
#  '저 ',
#  '소인 ',
#  '소생 ',
#  '저희 ',
#  '지말고 ',
#  '하지마 ',
#  '하지마라 ',
#  '다른 ',
#  '물론 ',
#  '또한 ',
#  '그리고 ',
#  '비길수 ',
#  '없다 ',
#  '해서는 ',
#  '안된다 ',
#  '뿐만 ',
#  '아니라 ',
#  '만이 ',
#  '아니다 ',
#  '만은 ',
#  '아니다 ',
#  '막론하고 ',
#  '관계없이 ',
#  '그치지 ',
#  '않다 ',
#  '그러나 ',
#  '그런데 ',
#  '하지만 ',
#  '든간에 ',
#  '논하지 ',
#  '않다 ',
#  '따지지 ',
#  '않다 ',
#  '설사 ',
#  '비록 ',
#  '더라도 ',
#  '아니면 ',
#  '만 ',
#  '못하다 ',
#  '하는 ',
#  '편이 ',
#  '낫다 ',
#  '불문하고 ',
#  '향하여 ',
#  '향해서 ',
#  '향하다 ',
#  '쪽으로 ',
#  '틈타 ',
#  '이용하여 ',
#  '타다 ',
#  '오르다 ',
#  '제외하고 ',
#  '이 ',
#  '외에 ',
#  '이 ',
# ...

# %%
# excel 파일 읽어오기
import pandas as pd

#kyobo = pd.read_excel(r"C:\Users\user\Desktop\ML\kyobo_w_description.xlsx", usecols='B, D, N')
descript_B = pd.read_excel(r"C:\Users\user\Desktop\ML\description_B.xlsx", usecols='D, M, N')

print(descript_B)
# Out:
#                                            상품명    분야  \
# 0                                          아몬드    소설
# 1                                   달러구트 꿈 백화점    소설
# 2    데미안(리커버 한정판)(초판본)(1919년 오리지널 초판본 패브릭 에디션)    소설
# 3                                보건교사 안은영(특별판)    소설
# 4                                     녹나무의 파수꾼    소설
# ..                                         ...   ...
# 350                                    습관의 재발견  자기계발
# 351                                  신경 끄기의 기술  자기계발
# 352                                     생각의 비밀  자기계발
# 353                          지금 하지 않으면 언제 하겠는가  자기계발
# 354                                      굿 라이프  자기계발
#
#                                            Description
# 0    &lt;완득이&gt;, &lt;위저드 베이커리&gt;를 잇는 제10회 창비청소년문학...
# 1    잠들어야만 입장 가능한 꿈 백화점에서 일어나는 비밀스럽고도 기묘하며 가슴 뭉클한 판...
# 2    헤르만 헤세 탄생 140주년 기념 초호화 패브릭 양장\n영혼의 성장 기록, 나를 찾...
# 3    본격 학원 명랑 미스터리 소설 \n출간 5주년 & 영상화 기념 리커버 특별판 출간!...
# ...

# %%
# 텍스트 전처리 사용자 정의함수
def text_preprocessor(s):
    import re

    ## (1) [], (), {}, <> 괄호와 괄호 안 문자 제거하기
    pattern = r'\([^)]*\)'  # ()
    s = re.sub(pattern=pattern, repl='', string=s)

    pattern = r'\[[^)]*\]'  # []
    s = re.sub(pattern=pattern, repl='', string=s)

    pattern = r'\<[^)]*\>'  # <>
    s = re.sub(pattern=pattern, repl='', string=s)

    pattern = r'\{[^)]*\}'  # {}
    s = re.sub(pattern=pattern, repl='', string=s)
    
    pattern = ' '.join(stop_words)
    s = re.sub(pattern=pattern, repl='', string=s)

    ## (2) '...외', '...총' 제거하기
    s = s.replace('...외', ' ')
    s = s.replace('...의', ' ')

    ## (3) 특수문자 제거
    pattern = r'[^a-zA-Z가-힣]'
    s = re.sub(pattern=pattern, repl=' ', string=s)
    s = s.replace('&lt;', '')
    s = s.replace('&gt;', '')

    ## (4) 단위 제거: cm, km, etc.
    units = ['mm', 'cm', 'km', 'ml', 'kg', 'g']
    for unit in units:
        s = s.lower() # 대문자를 소문자로 변환
        s = s.replace(unit, '')

    # (5) 공백 기준으로 분할하기
    s_split = s.split()

    # (6) 글자 1개만 있으면 제외하기
    s_list = []
    for word in s_split:
        if len(word) !=1:
            s_list.append(word)

    return s_list

# %%
def remove_stopwords(text):
    words = text.split()  # Split the text into words
    filtered_words = [word for word in words if word.lower() not in stop_words]  # Filter out stop words
    return ' '.join(filtered_words)  # Join the remaining words back into a text

# Apply the remove_stopwords function to the 'Description' column
descript_B['Description'] = descript_B['Description'].apply(remove_stopwords)

# Save the updated DataFrame to a new CSV file
descript_B.to_csv('updated_B.csv', index=False)

# %%
# excel file의 'Description' data toeknize 및 stopword 제거
descript_B['Description'] = descript_B['Description'].apply(remove_stopwords)
descript_B['Tokenized'] = descript_B['Description'].apply(lambda s: text_preprocessor(s))

print(descript_B['Tokenized'])
print('-------------'*5)
print(descript_B['Description'])
# Out:
# 0      [lt, 완득이, lt, 위저드, 베이커리, 잇는, 창비청소년문학상, 수상작, 감정...
# 1      [잠들어야만, 입장, 가능한, 백화점에서, 일어나는, 비밀스럽고도, 기묘하며, 가슴...
# 2      [헤르만, 헤세, 탄생, 주년, 기념, 초호화, 패브릭, 양장, 영혼의, 성장, 기...
# 3      [본격, 학원, 명랑, 미스터리, 소설, 출간, 주년, 영상화, 기념, 리커버, 특...
# 4      [사상, 최초, 한국, 중국, 일본, 대만, 세계, 동시, 출간, 나미야, 잡화점의...
#                              ...
# 350    [사소한, 행동으로, 위대한, 결과를, 만드는, 작은, 습관, 매년, 매월, 우리는...
# 351    [무한, 긍정만을, 강요하던, 기존의, 자기계발서는, 잊어라, 인생의, 터닝포인트를...
# 352    [매일, 번씩, 일간, 상상하고, 쓰고, 외쳐라, 무일푼에서, 시작해, 원의, 기업...
# 353    [원하는, 목표가, 있다면, 지금, 그것을, 이루어야, 한다, 타이탄의, 도구들, ...
# 354    [좋은, 프레임으로, 세상을, 바라볼, 찾아오는, 행복과, 삶의, 가치, 행복과, ...
# Name: Tokenized, Length: 355, dtype: object
# -----------------------------------------------------------------
# 0      &lt;완득이&gt;, &lt;위저드 베이커리&gt;를 잇는 제10회 창비청소년문학...
# 1      잠들어야만 입장 가능한 꿈 백화점에서 일어나는 비밀스럽고도 기묘하며 가슴 뭉클한 판...
# 2      헤르만 헤세 탄생 140주년 기념 초호화 패브릭 양장 영혼의 성장 기록, 나를 찾아...
# 3      본격 학원 명랑 미스터리 소설 출간 5주년 & 영상화 기념 리커버 특별판 출간! 2...
# ...

# %%
descript_B
# Out:
#                                            상품명    분야  \
# 0                                          아몬드    소설
# 1                                   달러구트 꿈 백화점    소설
# 2    데미안(리커버 한정판)(초판본)(1919년 오리지널 초판본 패브릭 에디션)    소설
# 3                                보건교사 안은영(특별판)    소설
# 4                                     녹나무의 파수꾼    소설
# ..                                         ...   ...
# 350                                    습관의 재발견  자기계발
# 351                                  신경 끄기의 기술  자기계발
# 352                                     생각의 비밀  자기계발
# 353                          지금 하지 않으면 언제 하겠는가  자기계발
# 354                                      굿 라이프  자기계발
#
#                                            Description  \
# 0    &lt;완득이&gt;, &lt;위저드 베이커리&gt;를 잇는 제10회 창비청소년문학...
# 1    잠들어야만 입장 가능한 꿈 백화점에서 일어나는 비밀스럽고도 기묘하며 가슴 뭉클한 판...
# 2    헤르만 헤세 탄생 140주년 기념 초호화 패브릭 양장 영혼의 성장 기록, 나를 찾아...
# 3    본격 학원 명랑 미스터리 소설 출간 5주년 & 영상화 기념 리커버 특별판 출간! 2...
# ...

# %%
descript_B.rename(columns={'상품명':'제목'}, inplace=True)

# %%
# remove stopwords from text
def remove_stopword(text):
    import re
    for word in stop_words:
        text = re.sub(word, ' ', text)
    return text

descript_B['Descript'] = descript_B['Description'].apply(remove_stopword)

# Display the updated DataFrame with stopwords removed
descript_B['Descript']
# Out:
# 0      &lt;완득이&gt; &lt;위 베이커리&gt; 잇 제10 창비청소년문학 수상작 '...
# 1      잠들어 입 가능  백화 일어 비밀스럽고 기묘  뭉클 판타 소  잠들어 입장   ‘달...
# 2      헤르 헤 탄 140 기 초호 패브 양 영혼 성 기록  찾아  《데미 1919 오리 ...
# 3      본 학  미스터 소 출 5  영상 기 리커 특별 출 2015 12 출간 꾸준 사랑 ...
# 4       최 한국·중국·일본·대  세 동 출 《나미 잡화 기적》 잇   감 대 《나미 잡화...
#                              ...
# 350    사소 행동으 위대 결 만드 ‘작 습관’   초    지키 못 거창 계획 세운다 작심...
# 351    “무 긍정 강요 기존 자기계발서 잊어라! 인생 터닝포인트 위  중요  남기  지워버...
# 352     100번씩 100 상상 쓰고 외쳐 무일푼 시작 4000  기업체  인생역 드라마 ...
# 353     목표    이루  《타이탄 도구들》   페리스  삶  소 가치 꿈 목표 이루 방법...
# 354     프레임으 세상 바  찾아 행복 삶  행복 인생 관 통찰 가득 『 라이프』 심리학 ...
# Name: Descript, Length: 355, dtype: object

# %%
descript_B
# Out:
#                                             제목    분야  \
# 0                                          아몬드    소설
# 1                                   달러구트 꿈 백화점    소설
# 2    데미안(리커버 한정판)(초판본)(1919년 오리지널 초판본 패브릭 에디션)    소설
# 3                                보건교사 안은영(특별판)    소설
# 4                                     녹나무의 파수꾼    소설
# ..                                         ...   ...
# 350                                    습관의 재발견  자기계발
# 351                                  신경 끄기의 기술  자기계발
# 352                                     생각의 비밀  자기계발
# 353                          지금 하지 않으면 언제 하겠는가  자기계발
# 354                                      굿 라이프  자기계발
#
#                                            Description  \
# 0    &lt;완득이&gt;, &lt;위저드 베이커리&gt;를 잇는 제10회 창비청소년문학...
# 1    잠들어야만 입장 가능한 꿈 백화점에서 일어나는 비밀스럽고도 기묘하며 가슴 뭉클한 판...
# 2    헤르만 헤세 탄생 140주년 기념 초호화 패브릭 양장 영혼의 성장 기록, 나를 찾아...
# 3    본격 학원 명랑 미스터리 소설 출간 5주년 & 영상화 기념 리커버 특별판 출간! 2...
# ...

# %%
descript_B['Descript'][0]
# Out:
# "&lt;완득이&gt; &lt;위 베이커리&gt; 잇 제10 창비청소년문학 수상작 '감정 느끼 못 소 특별 성 이야기이다 작  인물 타 관 맺 슬픔 공감 성장  과정 탁 묘사했다 열  소 선윤재 '감 표 불능증 앓  '아몬드 불리 편도체 작 분노 공포  느끼 못한다 타고 침착성 엄마 할머니 지극  덕    지냈 크리스마스이브 열  생 비극 사고  가족 잃는다 세상 홀 남겨 윤  '곤 나타난다 13  가족 품으 돌아  곤 분노   아이다 곤 윤재 화 쏟  감정 동요  윤  오히 쩔쩔 만다 윤재 어쩐 곤 밉  오히 궁금해진다  소 남 이해   특별 우정 쌓 간다 윤재  내면 변화 겪는데… 서 다 이유 '괴물' 불리  소 세상으  발   있을까?"

# %%
descript_B.to_csv(r"C:\Users\user\Desktop\ML\updated_B.csv", index=False)

# %%
descript_B = pd.read_csv(r"C:\Users\user\Desktop\ML\updated_B.csv")

# %%
descript_B
# Out:
#                                             제목    분야  \
# 0                                          아몬드    소설
# 1                                   달러구트 꿈 백화점    소설
# 2    데미안(리커버 한정판)(초판본)(1919년 오리지널 초판본 패브릭 에디션)    소설
# 3                                보건교사 안은영(특별판)    소설
# 4                                     녹나무의 파수꾼    소설
# ..                                         ...   ...
# 350                                    습관의 재발견  자기계발
# 351                                  신경 끄기의 기술  자기계발
# 352                                     생각의 비밀  자기계발
# 353                          지금 하지 않으면 언제 하겠는가  자기계발
# 354                                      굿 라이프  자기계발
#
#                                            Description  \
# 0    &lt;완득이&gt;, &lt;위저드 베이커리&gt;를 잇는 제10회 창비청소년문학...
# 1    잠들어야만 입장 가능한 꿈 백화점에서 일어나는 비밀스럽고도 기묘하며 가슴 뭉클한 판...
# 2    헤르만 헤세 탄생 140주년 기념 초호화 패브릭 양장 영혼의 성장 기록, 나를 찾아...
# 3    본격 학원 명랑 미스터리 소설 출간 5주년 & 영상화 기념 리커버 특별판 출간! 2...
# ...

# %%
# csv 파일의 Tokenized column의 요소들 하나의 list로 통합시키기
token_list_B = descript_B.Tokenized.values.tolist()
token_list_B
# Out:
# ["['lt', '완득이', 'lt', '위저드', '베이커리', '잇는', '창비청소년문학상', '수상작', '감정을', '느끼지', '못하는', '소년의', '특별한', '성장', '이야기이다', '작품', '인물들이', '타인과', '관계', '맺고', '슬픔에', '공감하며', '성장해', '나가는', '과정을', '탁월하게', '묘사했다', '열여섯', '소년', '선윤재는', '감정', '표현', '불능증', '앓고', '있다', '아몬드', '불리는', '편도체가', '작아', '분노도', '공포도', '느끼지', '못한다', '타고난', '침착성', '엄마와', '할머니의', '지극한', '사랑', '덕에', '없이', '지냈지만', '크리스마스이브이던', '열여섯', '번째', '생일날', '비극적인', '사고가', '일어나', '가족을', '잃는다', '세상에', '홀로', '남겨진', '윤재', '앞에', '곤이', '나타난다', '만에', '가족의', '품으로', '돌아오게', '곤이는', '분노로', '가득', '아이다', '곤이는', '윤재에게', '화를', '쏟아', '내지만', '감정의', '동요가', '없는', '윤재', '앞에서', '오히려', '쩔쩔매고', '만다', '윤재는', '어쩐지', '곤이가', '밉지', '않고', '오히려', '궁금해진다', '소년은', '남들이', '이해할', '없는', '특별한', '우정을', '쌓아', '간다', '윤재는', '조금씩', '내면의', '변화를', '겪는데', '서로', '다른', '이유로', '괴물', '이라', '불리는', '소년은', '세상으로', '발짝', '나아갈', '있을까']",
# ...

# %%
# string representations of lists를 actual lists로 convert
import ast

tokens_B = [ast.literal_eval(item) for item in token_list_B]

print(tokens_B)
# Out:
# [['lt', '완득이', 'lt', '위저드', '베이커리', '잇는', '창비청소년문학상', '수상작', '감정을', '느끼지', '못하는', '소년의', '특별한', '성장', '이야기이다', '작품', '인물들이', '타인과', '관계', '맺고', '슬픔에', '공감하며', '성장해', '나가는', '과정을', '탁월하게', '묘사했다', '열여섯', '소년', '선윤재는', '감정', '표현', '불능증', '앓고', '있다', '아몬드', '불리는', '편도체가', '작아', '분노도', '공포도', '느끼지', '못한다', '타고난', '침착성', '엄마와', '할머니의', '지극한', '사랑', '덕에', '없이', '지냈지만', '크리스마스이브이던', '열여섯', '번째', '생일날', '비극적인', '사고가', '일어나', '가족을', '잃는다', '세상에', '홀로', '남겨진', '윤재', '앞에', '곤이', '나타난다', '만에', '가족의', '품으로', '돌아오게', '곤이는', '분노로', '가득', '아이다', '곤이는', '윤재에게', '화를', '쏟아', '내지만', '감정의', '동요가', '없는', '윤재', '앞에서', '오히려', '쩔쩔매고', '만다', '윤재는', '어쩐지', '곤이가', '밉지', '않고', '오히려', '궁금해진다', '소년은', '남들이', '이해할', '없는', '특별한', '우정을', '쌓아', '간다', '윤재는', '조금씩', '내면의', '변화를', '겪는데', '서로', '다른', '이유로', '괴물', '이라', '불리는', '소년은', '세상으로', '발짝', '나아갈', '있을까'], ['잠들어야만', '입장', '가능한', '백화점에서', '일어나는', '비밀스럽고도', '기묘하며', '가슴', '뭉클한', '판타지', '소설', '여기는', '잠들어야만', '입장할', '있는', '달러구트', '백화점', '입니다', '잠들어야만', '입장할', '있는', '독특한',
# ...

# %%
# 리스트 내 단어들로 구성된 단일 리스트 만들기
flattened_B = [string for sublist in tokens_B for string in sublist]

print(flattened_B)
# Out:
# ['lt', '완득이', 'lt', '위저드', '베이커리', '잇는', '창비청소년문학상', '수상작', '감정을', '느끼지', '못하는', '소년의', '특별한', '성장', '이야기이다', '작품', '인물들이', '타인과', '관계', '맺고', '슬픔에', '공감하며', '성장해', '나가는', '과정을', '탁월하게', '묘사했다', '열여섯', '소년', '선윤재는', '감정', '표현', '불능증', '앓고', '있다', '아몬드', '불리는', '편도체가', '작아', '분노도', '공포도', '느끼지', '못한다', '타고난', '침착성', '엄마와', '할머니의', '지극한', '사랑', '덕에', '없이', '지냈지만', '크리스마스이브이던', '열여섯', '번째', '생일날', '비극적인', '사고가', '일어나', '가족을', '잃는다', '세상에', '홀로', '남겨진', '윤재', '앞에', '곤이', '나타난다', '만에', '가족의', '품으로', '돌아오게', '곤이는', '분노로', '가득', '아이다', '곤이는', '윤재에게', '화를', '쏟아', '내지만', '감정의', '동요가', '없는', '윤재', '앞에서', '오히려', '쩔쩔매고', '만다', '윤재는', '어쩐지', '곤이가', '밉지', '않고', '오히려', '궁금해진다', '소년은', '남들이', '이해할', '없는', '특별한', '우정을', '쌓아', '간다', '윤재는', '조금씩', '내면의', '변화를', '겪는데', '서로', '다른', '이유로', '괴물', '이라', '불리는', '소년은', '세상으로', '발짝', '나아갈', '있을까', '잠들어야만', '입장', '가능한', '백화점에서', '일어나는', '비밀스럽고도', '기묘하며', '가슴', '뭉클한', '판타지', '소설', '여기는', '잠들어야만', '입장할', '있는', '달러구트', '백화점', '입니다', '잠들어야만', '입장할', '있는', '독특한', '마
# ...

# %%
# 중복어 제거
vocab_B = list(set(flattened_B))

print(vocab_B)
# Out:
# ['새도', '근근이', '중세풍의', '스물일곱', '출력하기', '소외될', '않은', '도종환', '변역되어', '노트가', '균열을', '뇌과학의', '찾아오기를', '의사표시를', '멀쩡히', '흡수한', '직시하며', '받는다', '잠깐', '몰랐던', '결정을', '외치기에는', '가벼운', '연대와', '힘듦이', '발전할', '세였다', '갉아먹는', '공동경영자가', '반전을', '새로워지고자', '시심의', '포용하는', '주도하며', '요소들을', '우리를', '내려갔다', '억만장자로', '더해준다', '다르다고', '문장들까지', '이야기다', '것이라는', '담아내었다', '서지', '폴을', '회자되고', '잔혹한', '힘들었던', '르네상스', '강조하는', '허둥대지', '조명한다', '하이퍼리얼리즘', '성장할', '가치관에', '이과적', '새롭게', '제작하였다', '빠져들', '이유는', '바라보는', '만여', '남편의', '모험으로', '기회가', '주목하는', '행운', '움직일', '서스펜스가', '올라온', '인간관계가', '운영해나가며', '받음', '멀게만', '위기인지', '일조차', '대면하는', '변할', '제시카와', '선물한다', '보지', '살것을', '기성', '고통스럽고', '진실성', '감독의', '알아가고자', '고개를', '페이지터너라는', '정열', '발표했다', '부록에서는', '거시적인', '명제를', '당대', '수록', '감추려', '만부를', '자랑한다', '박물관이나', '헤르미온느를', '인간관계란', '학생과', '침투했다', '없다고', '무너질', '황제의', '연구실에서', '수록해', '질서는', '작품이', '애인', '게리', '효과는', '인식에서', '과정으로', '격차를', '여자아이의', '해나가면', '결합되어', '전화', '발견하게', '탐색하고', '보통의', '주택', '성공하고', '방정식과', '선한', '응원하고', '학년이', '루이스'
# ...

# %%
len(vocab_B)
# Out:
# 22266

# %%
def split_sentences(text):
    sentences = text.replace(". ",".")
    sentences = re.sub(r'([^\n\s\.\?!]+[^\n\.\?!]*[\.\?!])', r'\1\n', text).strip().split("\n")
    return sentences

# %%
import re
split_sentences(descript_B['Description'][0])
# Out:
# ['&lt;완득이&gt;, &lt;위저드 베이커리&gt;를 잇는 제10회 창비청소년문학상 수상작.',
#  " '감정을 느끼지 못하는' 소년의 특별한 성장 이야기이다.",
#  ' 작품 속 인물들이 타인과 관계 맺고 슬픔에 공감하며 성장해 나가는 과정을 탁월하게 묘사했다.',
#  " 열여섯 살 소년 선윤재는 '감정 표현 불능증'을 앓고 있다.",
#  " '아몬드'라 불리는 편도체가 작아 분노도 공포도 잘 느끼지 못한다.",
#  ' 타고난 침착성, 엄마와 할머니의 지극한 사랑 덕에 별 탈 없이 지냈지만, 크리스마스이브이던 열여섯 번째 생일날 비극적인 사고가 일어나 가족을 잃는다.',
#  " 세상에 홀로 남겨진 윤재 앞에 '곤이'가 나타난다.",
#  ' 13년 만에 가족의 품으로 돌아오게 된 곤이는 분노로 가득 찬 아이다.',
#  ' 곤이는 윤재에게 화를 쏟아 내지만, 감정의 동요가 없는 윤재 앞에서 오히려 쩔쩔매고 만다.',
#  ' 윤재는 어쩐지 곤이가 밉지 않고, 오히려 궁금해진다.',
#  ' 두 소년은 남들이 이해할 수 없는 특별한 우정을 쌓아 간다.',
#  ' 윤재는 조금씩 내면의 변화를 겪는데….',
#  " 서로 다른 이유로 '괴물'이라 불리는 두 소년은 세상으로 한 발짝 나아갈 수 있을까?"]

# %%
from konlpy.tag import Okt
import re

def split_noun_sentences(text):
    okt = Okt()
    sentences = text.replace(". ",".")
    sentences = re.sub(r'([^\n\s\.\?!]+[^\n\.\?!]*[\.\?!])', r'\1\n', sentences).strip().split("\n")
    
    result = []
    for sentence in sentences:
        if len(sentence) == 0:
            continue
        sentence_pos = okt.pos(sentence, stem=True)
        nouns = [word for word, pos in sentence_pos if pos == 'Noun']
        if len(nouns) == 1:
            continue
        result.append(' '.join(nouns) + '.')
        
    return result

# %%
from krwordrank.word import KRWordRank

min_count = 1   # 단어의 최소 출현 빈도수 (그래프 생성 시)
max_length = 10 # 단어의 최대 길이
wordrank_extractor = KRWordRank(min_count=min_count, max_length=max_length)
beta = 0.85    # PageRank의 decaying factor beta
max_iter = 20
texts = split_noun_sentences(descript_B['Description'][0])
keywords, rank, graph = wordrank_extractor.extract(texts, beta, max_iter)
for word, r in sorted(keywords.items(), key=lambda x:x[1], reverse=True):
        print('%8s:\t%.4f' % (word, r))
# Out:
#       여섯:	2.6628
#       윤재:	2.6225
#       감정:	2.4779
#      위저드:	1.9190
#       분노:	1.6818
#      완득이:	1.6023
#       소년:	1.5900
#      문학상:	1.5238
#     수상작.:	1.4609
#      아몬드:	1.3289
#       엄마:	1.3131
#       지극:	1.3081
#      청소년:	1.2469
#       세상:	1.2149
#       성장:	1.2114
#       가족:	1.1905
#       과정:	1.1103
#       사고:	1.0482
#       침착:	1.0426
#       관계:	1.0278
#      공포.:	1.0218
#      편도체:	1.0014
#      오히려:	0.9963
#       내면:	0.9238
#       할머:	0.9085
#       공감:	0.8928
#       이유:	0.8756
#       증.:	0.8549
#       베이:	0.8454
#       타인:	0.8311
#       수.:	0.8308
#       슬픔:	0.8235
#       창비:	0.7969
#       우정:	0.7927
#       불능:	0.7891
#      묘사.:	0.7839
#       표현:	0.7801
#       크리:	0.7757
#     이야기.:	0.7564
#       서로:	0.7310
#       작품:	0.7146
#       간다:	0.7135
#       다른:	0.6936
#       발짝:	0.6730
#       아이:	0.6697
#      변화.:	0.6461
#      선윤재:	0.6452
#       인물:	0.6408
#       홀로:	0.6337
#       동요:	0.6296
#       어쩐:	0.6021
#       비극:	0.5370
# ...

# %%
keyword_B_0 = [(word, r) for word, r in sorted(keywords.items(), key=lambda x: x[1], reverse=True)]
print(keyword_B_0)
# Out:
# [('여섯', 2.6628400082805075), ('윤재', 2.622498019838229), ('감정', 2.477896540721739), ('위저드', 1.9189525385847466), ('분노', 1.6818073534259286), ('완득이', 1.602252536362442), ('소년', 1.5899638384561756), ('문학상', 1.5238171962809393), ('수상작.', 1.4608976869780776), ('아몬드', 1.3289019225384315), ('엄마', 1.313096845593718), ('지극', 1.308144215619015), ('청소년', 1.2469239845055546), ('세상', 1.2148852729435902), ('성장', 1.2114493085921731), ('가족', 1.1905401348125895), ('과정', 1.1103018409486425), ('사고', 1.048241009023564), ('침착', 1.0425765278840335), ('관계', 1.0278217846814797), ('공포.', 1.0217558989833375), ('편도체', 1.0013751960621713), ('오히려', 0.9962876170031448), ('내면', 0.9237831817138873), ('할머', 0.90851990083684), ('공감', 0.8928093490297686), ('이유', 0.8755573317969086), ('증.', 0.854859367082409), ('베이', 0.8454189504650452), ('타인', 0.8310892180549079), ('수.', 0.8307806215652573), ('슬픔', 0.8234805341322797), ('창비', 0.7968541980881304), ('우정', 0.7926956908987998), ('불능', 0.7890815869833608), ('묘사.', 0.783908
# ...
